# %% [markdown]
# ### Day 1 - Data Wrangling

# %%
#Importando bibliotecas
import numpy as np
import pandas as pd

# %%
#Importando os dados
ceaps = pd.read_csv('despesa_ceaps_2022.csv', sep=';', decimal=',', skiprows=1, encoding='ISO-8859-1')
ceaps.head(20)
# Out:
#      ANO  MES       SENADOR  \
# 0   2022    1  ACIR GURGACZ
# 1   2022    1  ACIR GURGACZ
# 2   2022    1  ACIR GURGACZ
# 3   2022    1  ACIR GURGACZ
# 4   2022    1  ACIR GURGACZ
# 5   2022    1  ACIR GURGACZ
# 6   2022    2  ACIR GURGACZ
# 7   2022    2  ACIR GURGACZ
# 8   2022    2  ACIR GURGACZ
# 9   2022    2  ACIR GURGACZ
# 10  2022    2  ACIR GURGACZ
# 11  2022    2  ACIR GURGACZ
# 12  2022    2  ACIR GURGACZ
# 13  2022    2  ACIR GURGACZ
# 14  2022    2  ACIR GURGACZ
# 15  2022    2  ACIR GURGACZ
# 16  2022    2  ACIR GURGACZ
# 17  2022    2  ACIR GURGACZ
# 18  2022    2  ACIR GURGACZ
# 19  2022    2  ACIR GURGACZ
#
#                                          TIPO_DESPESA            CNPJ_CPF  \
# 0   Aluguel de imóveis para escritório político, c...      004.948.028-63
# 1                 Divulgação da atividade parlamentar  26.320.603/0001-64
# 2                 Divulgação da atividade parlamentar  13.659.201/0001-47
# 3                 Divulgação da atividade parlamentar  23.652.846/0001-01
# 4                 Divulgação da atividade parlamentar  08.941.827/0001-01
# 5   Passagens aéreas, aquáticas e terrestres nacio...  17.872.428/0001-27
# 6   Aluguel de imóveis para escritório político, c...      004.948.028-63
# 7   Contratação de consultorias, assessorias, pesq...  13.659.201/0001-47
# 8                 Divulgação da atividade parlamentar  26.320.603/0001-64
# 9                 Divulgação da atividade parlamentar  41.845.127/0001-99
# 10                Divulgação da atividade parlamentar  37.153.908/0001-45
# 11                Divulgação da atividade parlamentar  37.153.908/0001-45
# 12                Divulgação da atividade parlamentar  23.652.846/0001-01
# 13                Divulgação da atividade parlamentar  08.941.827/0001-01
# 14                Divulgação da atividade parlamentar  30.637.754/0001-18
# 15  Passagens aéreas, aquáticas e terrestres nacio...  17.872.428/0001-27
# 16  Passagens aéreas, aquáticas e terrestres nacio...  17.872.428/0001-27
# 17  Passagens aéreas, aquáticas e terrestres nacio...  17.872.428/0001-27
# 18  Passagens aéreas, aquáticas e terrestres nacio...  17.872.428/0001-27
# 19  Passagens aéreas, aquáticas e terrestres nacio...  17.872.428/0001-27
#
#                                            FORNECEDOR          DOCUMENTO  \
# 0                       GILBERTO PISELO DO NASCIMENTO             001/22
# 1                                       INFORMANAHORA  000000000000310/A
# 2                     LINHA PURPURA FOTO E VIDEO LTDA                107
# 3                   ROBERTO GUTIERREZ DA ROCHA M.E.I.                187
# 4   RONDONIA DINÂMICA COM. E SERV. DE INFORMÁTICA ...  000000000001772/A
# 5             1000.36        2174218
# 6             6000.00        2174221
# 7             6000.00        2174981
# 8             1500.00        2174982
# 9             1000.00        2174219
# 10            1000.00        2174980
# 11            1000.00        2175731
# 12            1000.00        2174985
# 13            1000.00        2174984
# 14            1000.00        2175728
# 15            1895.00        2174224
# 16            2296.42        2174223
# 17            2333.82        2174979
# 18            1817.19        2174983
# 19            2530.00        2175726

# %%
# Obtendo informações gerais
ceaps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9465 entries, 0 to 9464
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                9465 non-null   int64
#  1   MES                9465 non-null   int64
#  2   SENADOR            9465 non-null   object
#  3   TIPO_DESPESA       9465 non-null   object
#  4   CNPJ_CPF           9465 non-null   object
#  5   FORNECEDOR         9465 non-null   object
#  6   DOCUMENTO          8964 non-null   object
#  7   DATA               9465 non-null   object
#  8   DETALHAMENTO       5028 non-null   object
#  9   VALOR_REEMBOLSADO  9465 non-null   float64
#  10  COD_DOCUMENTO      9465 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 813.5+ KB

# %% [markdown]
# Com as informações obtidas percebemos que as colunas 'DOCUMENTO' e 'DETALHAMENTO' apresentam dados faltantes e a coluna 'DATA' foi incorretamente identificada como objeto.

# %%
#Vamos corrigir a data para o formato correto
ceaps['DATA_CORRETA'] = pd.to_datetime(ceaps['DATA'], format="%d/%m/%Y", errors='coerce')
ceaps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9465 entries, 0 to 9464
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                9465 non-null   int64
#  1   MES                9465 non-null   int64
#  2   SENADOR            9465 non-null   object
#  3   TIPO_DESPESA       9465 non-null   object
#  4   CNPJ_CPF           9465 non-null   object
#  5   FORNECEDOR         9465 non-null   object
#  6   DOCUMENTO          8964 non-null   object
#  7   DATA               9465 non-null   object
#  8   DETALHAMENTO       5028 non-null   object
#  9   VALOR_REEMBOLSADO  9465 non-null   float64
#  10  COD_DOCUMENTO      9465 non-null   int64
#  11  DATA_CORRETA       9465 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 887.5+ KB

# %%
ceaps.isnull().sum() #verificando quantas informações faltantes temos
# Out:
# ANO                     0
# MES                     0
# SENADOR                 0
# TIPO_DESPESA            0
# CNPJ_CPF                0
# FORNECEDOR              0
# DOCUMENTO             501
# DATA                    0
# DETALHAMENTO         4437
# VALOR_REEMBOLSADO       0
# COD_DOCUMENTO           0
# DATA_CORRETA            0
# dtype: int64

# %%
#Utilizando a coluna 'COD_DOCUMENTO' para verificar se temos dados duplicados
ceaps[ceaps['COD_DOCUMENTO'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [ANO, MES, SENADOR, TIPO_DESPESA, CNPJ_CPF, FORNECEDOR, DOCUMENTO, DATA, DETALHAMENTO, VALOR_REEMBOLSADO, COD_DOCUMENTO, DATA_CORRETA]
# Index: []
